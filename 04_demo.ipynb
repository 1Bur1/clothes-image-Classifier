# %% [markdown]
# <a href="https://colab.research.google.com/github/1Bur1/clothes-image-Classifier/blob/main/04_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 04 Demo - Live Clothing Classifier
# Upload a clothing photo and the model predicts the category.
# **Run cells top to bottom.**
#
# Prerequisite: run `01_train.ipynb` first so `models/fashion_cnn.h5` exists.

# %% [markdown]
# ## Step 1 - Install Dependencies

# %%
import subprocess, sys
# sys.executable ensures pip works on Windows
subprocess.run([sys.executable, '-m', 'pip', 'install', 'gradio', 'pillow', '-q'], check=True)
print('Done.')
# Out:
# Done.

# %% [markdown]
# ## Step 2 - Load Model

# %%
import numpy as np
import gradio as gr
from tensorflow import keras
from PIL import Image

CLASS_NAMES = [
    'T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
    'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot'
]

model = keras.models.load_model('../models/fashion_cnn.h5')
print(f'Model loaded. Input shape: {model.input_shape}')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1095/2033304609.py in <cell line: 0>()
#       9 ]
#      10
# ---> 11 model = keras.models.load_model('../models/fashion_cnn.h5')
#      12 print(f'Model loaded. Input shape: {model.input_shape}')
#
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_api.py in load_model(filepath, custom_objects, compile, safe_mode)
#     194         )
#     195     if str(filepath).endswith((".h5", ".hdf5")):
# --> 196         return legacy_h5_format.load_model_from_hdf5(
#     197             filepath,
#     198             custom_objects=custom_objects,
#
# /usr/local/lib/python3.12/dist-packages/keras/src/legacy/saving/legacy_h5_format.py in load_model_from_hdf5(filepath, custom_objects, compile, safe_mode)
#     116     opened_new_file = not isinstance(filepath, h5py.File)
#     117     if opened_new_file:
# ...

# %% [markdown]
# ## Step 3 - Prediction Function
#
# Preprocessing: grayscale → resize 28x28 → normalize → reshape(1,28,28,1)

# %%
def predict(image):
    if image is None:
        return {n: 0.0 for n in CLASS_NAMES}
    img = Image.fromarray(image).convert('L').resize((28, 28))
    arr = np.array(img) / 255.0
    arr = arr.reshape(1, 28, 28, 1)
    probs = model.predict(arr, verbose=0)[0]
    return {CLASS_NAMES[i]: float(probs[i]) for i in range(10)}

print('predict() ready.')

# %% [markdown]
# ## Step 4 - Launch Web App
#
# Starts a local server and opens the browser at `http://127.0.0.1:7860`.

# %%
gr.Interface(
    fn=predict,
    inputs=gr.Image(type='numpy', label='Upload a clothing photo'),
    outputs=gr.Label(num_top_classes=3, label='Top 3 Predictions'),
    title='Fashion-MNIST Clothing Classifier',
    description='Categories: ' + ', '.join(CLASS_NAMES),
).launch()
